# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
# import random
# import re
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#your code
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
table = soup.find_all('div',{'class':'Box'})[1]
tags = table.find_all('h1') 
text = [i.text.strip().split("\n") for i in tags]
text
# Out:
# [['Jason Quense'],
#  ['yup'],
#  ['Hadley Wickham'],
#  ['r4ds'],
#  ['Ran Luo'],
#  ['jocs.github.io'],
#  ['Wojciech Maj'],
#  ['react-pdf'],
#  ['Emmanuel Garcia'],
#  ['turn.js'],
#  ['Francois Zaninotto'],
#  ['Faker'],
#  ['Felix Becker'],
#  ['php-language-server'],
#  ['Tanner Linsley'],
#  ['react-table'],
#  ['William Falcon'],
#  ['pytorch-lightning'],
#  ['Björn Kimminich'],
#  ['juice-shop'],
#  ['Gregor Santner'],
#  ['markor'],
#  ['David Rodríguez'],
#  ['byebug'],
#  ['Anton Babenko'],
#  ['terraform-best-practices'],
#  ['Florimond Manca'],
#  ['awesome-asgi'],
#  ['francisco souza'],
#  ['go-dockerclient'],
#  ['Colin Fay'],
#  ['nessy'],
#  ['Megan Marsh'],
#  ['SurpriseFlowers'],
#  ['Krzysztof Magiera'],
#  ['react-native-gesture-handler'],
#  ['Nicolas Widart'],
#  ['laravel-modules'],
#  ['Zac Sweers'],
#  ['CatchUp'],
#  ['Julien Danjou'],
#  ['tenacity'],
#  ['Andreas Mueller'],
#  ['word_cloud'],
#  ['Alexander Bezobchuk'],
#  ['go-trie'],
# ...

# %%
#your code

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
import re
url='https://github.com/trending/python?since=daily'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
table = soup.find_all('div',{'class':'Box'})[1]
tags = table.find_all('span',{'class':'text-normal'}) 
text = [i.text.strip().split("\n") for i in tags]
text_clean=[re.sub('\W','',x) for i in text for x in i]
text_clean
# Out:
# ['openai',
#  'openai',
#  'iqiyi',
#  'ansible',
#  'OUCMachineLearning',
#  'd2lai',
#  'rusty1s',
#  'Morizeyao',
#  'publicapis',
#  'openmmlab',
#  'locustio',
#  'awssamples',
#  'pandasdev',
#  'kerasteam',
#  'wojciech',
#  'megviimodel',
#  'clovaai',
#  'minimaxir',
#  'huggingface',
#  'wangshub',
#  'OpenNMT',
#  'qqwweee',
#  'PaddlePaddle',
#  'facebookresearch',
#  'microsoft']

# %%
#your code#

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
table = soup.find_all('div',{'id':'bodyContent'})[0]
image = table.find_all('a',{'class':'image'})
src=[i.find('img')['src'] for i in image]
src
# Out:
# ['//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/7/71/Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg/170px-Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg',
#  '//upload.wikimedia.org/wikipedia/en/thumb/4/4e/Steamboat-willie.jpg/170px-Steamboat-willie.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/5/57/Walt_Disney_1935.jpg/170px-Walt_Disney_1935.jpg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python_(programming_language)' 
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
table = soup.find_all('div',{'id':'bodyContent'})[0]
links = table.find_all('a', attrs={'href': re.compile("^http://")}) 
links_href=[i.get('href') for i in links]
links_href
# Out:
# ['http://www.amk.ca/python/writing/gvr-interview',
#  'http://effbot.org/zone/call-by-object.htm',
#  'http://www.2ality.com/2013/02/javascript-influences.html',
#  'http://speakingjs.com/es5/ch03.html',
#  'http://ring-lang.sourceforge.net/doc1.6/introduction.html#ring-and-other-languages',
#  'http://nondot.org/sabre/',
#  'http://www.artima.com/intv/pythonP.html',
#  'http://www.nongnu.org/pydbc/',
#  'http://www.wayforward.net/pycontract/',
#  'http://shop.oreilly.com/product/9780596007973.do',
#  'http://ebeab.com/2014/01/21/python-culture/',
#  'http://python.net/~goodger/projects/pycon/2007/idiomatic/handout.html',
#  'http://python.net/crew/mwh/hacks/objectthink.html',
#  'http://www.secnetix.de/~olli/Python/block_indentation.hawk',
#  'http://neopythonic.blogspot.be/2009/04/tail-recursion-elimination.html',
#  'http://www.artima.com/weblogs/viewpost.jsp?thread=147358',
#  'http://mypy-lang.org/',
# ...

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code
url ='https://uscode.house.gov/download/download.shtml' 
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
table = soup.find_all('div',{'class':'uscitemlist'})[0]
titles = table.find_all('div',{'class':'usctitle'})
usa_titles = [title.text.strip().split("\n") for title in titles]
usa_titles
# Out:
# [['All titles in the format selected compressed into a zip archive.'],
#  [''],
#  ['Title 1 - General Provisions ٭'],
#  ['Title 2 - The Congress'],
#  ['Title 3 - The President ٭'],
#  ['Title 4 - Flag and Seal, Seat of Government, and the States ٭'],
#  ['Title 5 - Government Organization and Employees ٭'],
#  ['Title 7 - Agriculture'],
#  ['Title 8 - Aliens and Nationality'],
#  ['Title 9 - Arbitration ٭'],
#  ['Title 10 - Armed Forces ٭'],
#  ['Title 11 - Bankruptcy ٭'],
#  ['Title 12 - Banks and Banking'],
#  ['Title 13 - Census ٭'],
#  ['Title 14 - Coast Guard ٭'],
#  ['Title 15 - Commerce and Trade'],
#  ['Title 16 - Conservation'],
#  ['Title 17 - Copyrights ٭'],
#  ['Title 18 - Crimes and Criminal Procedure ٭'],
#  ['Title 19 - Customs Duties'],
#  ['Title 20 - Education'],
#  ['Title 21 - Food and Drugs'],
#  ['Title 22 - Foreign Relations and Intercourse'],
#  ['Title 23 - Highways ٭'],
#  ['Title 24 - Hospitals and Asylums'],
#  ['Title 25 - Indians'],
# ...

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
table = soup.find_all('div',{'class':'query-results pat-pager'})[0]
most_wanted  = [i.text.strip().split("\n") for i in table.find_all('h3',{'class':'title'})]
most_wanted
# Out:
# [['JASON DEREK BROWN'],
#  ['ALEXIS FLORES'],
#  ['EUGENE PALMER'],
#  ['SANTIAGO VILLALBA MEDEROS'],
#  ['RAFAEL CARO-QUINTERO'],
#  ['ROBERT WILLIAM FISHER'],
#  ['BHADRESHKUMAR CHETANBHAI PATEL'],
#  ['ARNOLDO JIMENEZ'],
#  ['ALEJANDRO ROSALES CASTILLO'],
#  ['YASER ABDEL SAID']]

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'
soup=BeautifulSoup((requests.get(url).content),'lxml')
table=soup.find_all('tbody',{'id':'tbody'})[0]
earthquakes=[i.text.strip().split("\xa0") for i in table.find_all('tr')]
earthquakes_frame=pd.DataFrame(earthquakes,columns=['update',1,2,'time','N/S',5,'lat','N/S',8,'long','place'])
earthquakes_frame=earthquakes_frame.drop([1,2,5,8],axis=1)
earthquakes_frame
# Out:
#                       update                          time N/S     lat N/S  \
# 0       earthquake2019-11-08      22:51:34.409min ago34.38   N   97.36   W
# 1       earthquake2019-11-08       22:35:00.026min ago3.33   N  123.35   E
# 2       earthquake2019-11-08      22:22:21.039min ago38.22   N   42.83   E
# 3   2IIIearthquake2019-11-08  21:55:02.21hr 06min ago34.28   N  119.28   W
# 4       earthquake2019-11-08  21:38:47.01hr 22min ago31.83   S   71.33   W
# 5       earthquake2019-11-08  21:38:01.71hr 23min ago45.38   N   26.31   E
# 6       earthquake2019-11-08  21:33:32.31hr 27min ago34.32   N  119.28   W
# 7       earthquake2019-11-08  21:30:09.41hr 31min ago34.26   N  119.28   W
# 8       earthquake2019-11-08  21:20:26.21hr 40min ago42.45   N   13.34   E
# 9      Fearthquake2019-11-08  21:03:42.01hr 57min ago43.68   N  146.98   E
# 10      earthquake2019-11-08  21:02:28.01hr 58min ago21.83   S   68.53   W
# ...

# %%
#your code

# %% [markdown]
# #### Display the date, and title of upcoming hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'
#only one hackthon event

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'
soup=BeautifulSoup((requests.get(url).content),'lxml')
table=soup.find_all('body',{'id':'www-wikipedia-org'})[0]
find_=['strong']
languages=[i.text.strip().split("\n") for i in table.find_all(find_)]
languages
# Out:
# [['The Free Encyclopedia'],
#  ['English'],
#  ['Español'],
#  ['日本語'],
#  ['Deutsch'],
#  ['Русский'],
#  ['Français'],
#  ['Italiano'],
#  ['中文'],
#  ['Português'],
#  ['Polski'],
#  ['Download Wikipedia for Android or iOS']]

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'
soup=BeautifulSoup((requests.get(url).content),'lxml')
table=soup.find_all('div',{'class':'grid-row dgu-topics'})[0]
table
find_=['h2']
avalaible_datasets=[i.text.strip().split("\n") for i in table.find_all(find_)]
avalaible_datasets
# Out:
# [['Business and economy'],
#  ['Crime and justice'],
#  ['Defence'],
#  ['Education'],
#  ['Environment'],
#  ['Government'],
#  ['Government spending'],
#  ['Health'],
#  ['Mapping'],
#  ['Society'],
#  ['Towns and cities'],
#  ['Transport']]

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
import pandas as pd
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'
soup=BeautifulSoup((requests.get(url).content),'lxml')
table=soup.find_all('table',{'class':'wikitable sortable'})[0]
table
find_=['tr']
languages_nat=[i.text.strip().split("\n") for i in table.find_all(find_)]
languages_nat=pd.DataFrame(languages_nat)
languages_nat=languages_nat.drop([1,3,5,7,8,9,11],axis=1)
languages_nat
# Out:
#       0                                      2                  4   \
# 0   Rank                               Language  Country of Origin
# 1      1                           Mandarin [9]              China
# 2      2                                Spanish              Spain
# 3      3                                English     United Kingdom
# 4      4                              Hindi[10]              India
# ..   ...                                    ...                ...
# 87    87                                  Czech     Czech Republic
# 88    88                   Taʽizzi-Adeni Arabic              Yemen
# 89    89                                 Uyghur              China
# 90    90  Min Dong Chinese (language family)[9]              China
# 91    91                                Sylheti         Bangladesh
#
#                    6                          10                         12  \
# 0   TotalCountries[a]  % of the World population
# ...

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'
soup=BeautifulSoup((requests.get(url).content),'lxml')
table=soup.find_all('div',{'class':'lister'})[0]
row_find=['td',{'class':'ratingcolumn imbdRating'}]
rating_films=[i.text.strip().split("\n") for i in table.find_all(row_find)]
rating_films

chars = "XY"
sub_cadenas = ["".join(g) 
              for (v,g) in groupby(cadena, key=lambda x: x in chars)
              if v]

#aquí podemos 

#rating_films_frame=pd.DataFrame(rating_films)
#drop_c=[3,4,5,6,7]
#rat_films_clean=rating_films_frame.drop(drop_c,axis=1)
#rat_films_clean.head()
# Out:
# [[''],
#  ['1.', '      Sueños de libertad', '(1994)'],
#  ['9.2'],
#  ['12345678910 ', '', '', '', 'NOT YET RELEASED', ' ', '', 'Seen'],
#  [''],
#  [''],
#  ['2.', '      El Padrino', '(1972)'],
#  ['9.1'],
#  ['12345678910 ', '', '', '', 'NOT YET RELEASED', ' ', '', 'Seen'],
#  [''],
#  [''],
#  ['3.', '      El padrino 2a parte', '(1974)'],
#  ['9.0'],
#  ['12345678910 ', '', '', '', 'NOT YET RELEASED', ' ', '', 'Seen'],
#  [''],
#  [''],
#  ['4.', '      Batman: El Caballero de la Noche', '(2008)'],
#  ['9.0'],
#  ['12345678910 ', '', '', '', 'NOT YET RELEASED', ' ', '', 'Seen'],
#  [''],
#  [''],
#  ['5.', '      12 hombres en pugna', '(1957)'],
#  ['8.9'],
#  ['12345678910 ', '', '', '', 'NOT YET RELEASED', ' ', '', 'Seen'],
#  [''],
#  [''],
#  ['6.', '      La lista de Schindler', '(1993)'],
#  ['8.9'],
#  ['12345678910 ', '', '', '', 'NOT YET RELEASED', ' ', '', 'Seen'],
#  [''],
#  [''],
#  ['7.', '      El señor de los anillos - El retorno del rey', '(2003)'],
# ...

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
